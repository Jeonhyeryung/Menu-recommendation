# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 데이터프레임 만들기

# %%
# %cd /content/drive/MyDrive/data/result
# Out:
# /content/drive/MyDrive/data/result

# %%
df_bert = pd.read_csv('bert_ctg_pp.csv')
df_bert
# Out:
#      Unnamed: 0  Unnamed: 0.1  user       item category property
# 0             0         45320  4532     꽁치레몬구이       한식      구이류
# 1             1         45321  4532      순살닭갈비       한식      고기류
# 2             2         45322  4532  치킨핑거/요거트D       양식   패스트푸드류
# 3            10         45330  4533     꽃게된장찌개       한식      찌개류
# 4            11         45331  4533      옥수수스프       양식       국류
# ..          ...           ...   ...        ...      ...      ...
# 148         491         45811  4581  치킨핑거/요거트D       양식   패스트푸드류
# 149         492         45812  4581     데리야끼파닭       양식      고기류
# 150         500         45820  4582     참치채소볶음       한식      볶음류
# 151         501         45821  4582     참치김치볶음       한식      볶음류
# 152         502         45822  4582    수제오징어튀김       한식      튀김류
#
# [153 rows x 6 columns]

# %%
user = df_bert['user'].unique()
menu_list = list(df_bert['item'])
ctg = list(df_bert['category'])
pp = list(df_bert['property'])

# %%
idx0 = list(range(0, len(menu_list), 3))
idx1 = list(range(1, len(menu_list), 3))
idx2 = list(range(2, len(menu_list), 3))

# %%
# firstrec 생성
firstrec = []
ctg1 = []
pp1 = []
for idx in idx0:
  firstrec.append(menu_list[idx])
  ctg1.append(ctg[idx])
  pp1.append(pp[idx])

# %%
first = pd.DataFrame([user,firstrec,ctg1,pp1], index = ['user','firstrec','ctg1','pp1'])
first = first.transpose()

# %%
# secondrec 생성
secondrec = []
ctg2 = []
pp2 = []
for idx in idx1:
  secondrec.append(menu_list[idx])
  ctg2.append(ctg[idx])
  pp2.append(pp[idx])

# %%
second = pd.DataFrame([user,secondrec,ctg2,pp2], index = ['user','secondrec','ctg2','pp2'])
second = second.transpose()

# %%
# thirdrec 생성
thirdrec = []
ctg3 = []
pp3 = []
for idx in idx2:
  thirdrec.append(menu_list[idx])
  ctg3.append(ctg[idx])
  pp3.append(pp[idx])

# %%
third = pd.DataFrame([user,thirdrec,ctg3,pp3], index = ['user','thirdrec','ctg3','pp3'])
third = third.transpose()

# %%
first
# Out:
#     user   firstrec ctg1   pp1
# 0   4532     꽁치레몬구이   한식   구이류
# 1   4533     꽃게된장찌개   한식   찌개류
# 2   4534      가쯔오장국   한식    국류
# 3   4535     참치김치볶음   한식   볶음류
# 4   4536       오징어국   한식    국류
# 5   4537      가쯔오장국   한식    국류
# 6   4538     꽃게된장찌개   한식   찌개류
# 7   4539     동파삼겹수육   중식   고기류
# 8   4540      돼지갈비찜   한식    찜류
# 9   4541  모둠튀김*칠리소스   양식   튀김류
# 10  4542      생선커틀릿   일식   튀김류
# 11  4543  모둠튀김*칠리소스   양식   튀김류
# 12  4544  모둠튀김*칠리소스   양식   튀김류
# 13  4545     곤약어묵볶음   한식   볶음류
# 14  4546       쑥갓나물   한식   무침류
# 15  4547     통도라지구이   한식   구이류
# 16  4548      유부김칫국   한식    국류
# 17  4549     곤약어묵볶음   한식   볶음류
# 18  4550      가쯔오장국   한식    국류
# 19  4551      햄계란말이   한식    전류
# 20  4552  모둠튀김*칠리소스   양식   튀김류
# 21  4553      꽈리고추찜   한식    찜류
# 22  4554     꼬시래기무침   한식   무침류
# 23  4555     곤약어묵볶음   한식   볶음류
# 24  4556      가쯔오장국   한식    국류
# 25  4557    파래김*양념장   한식  샐러드류
# 26  4558     쇠고기장조림   한식   고기류
# 27  4559     맑은콩나물국   한식    국류
# 28  4560      가쯔오장국   한식    국류
# 29  4561  모둠튀김*칠리소스   양식   튀김류
# 30  4562      군만두*장   한식   튀김류
# 31  4563     꽃게된장찌개   한식   찌개류
# 32  4564     사골우거지국   한식    국류
# 33  4565    모듬소세지볶음   한식   볶음류
# 34  4566    마늘종호두조림   한식   조림류
# 35  4567     고구마그라탕   한식    탕류
# 36  4568     우거지된장국   한식    국류
# 37  4569    연근깨소스무침   한식   무침류
# 38  4570       누룽지탕   한식    탕류
# 39  4571      가쯔오장국   한식    국류
# 40  4572    고추잡채*꽃빵   양식    빵류
# 41  4573    파래김*양념장   한식  샐러드류
# 42  4574    고추잡채*꽃빵   양식    빵류
# 43  4575     곤약어묵볶음   한식   볶음류
# 44  4576      순살닭갈비   한식   고기류
# 45  4577      수수부꾸미   한식    전류
# 46  4578   비엔나구이*케찹   한식   구이류
# 47  4579     올챙이만두국   한식    국류
# 48  4580       순두부국   한식    국류
# 49  4581     등갈비김치찜   한식    찜류
# 50  4582     참치채소볶음   한식   볶음류

# %% [markdown]
# # 원본 데이터 전처리

# %% [markdown]
# ## 정답값만 뽑기

# %%
origin = pd.read_csv('/content/drive/Shareddrives/DSL_Modeling_B/result/origin.csv')

# %%
user = origin['user'].unique()

# %%
org = origin.set_index('user')

# %%
answer_org = []

for i in range(len(user)):
  lst = org.loc[user[i]]['item'].tolist()
  answer_org.append(lst[-1])

# %%
true = pd.DataFrame([user,answer_org ], index = ['user','Menu']).transpose()

# %% [markdown]
# ## category, property 부여

# %%
true['category'] = 0
true['property'] = 0

# %%
cp = pd.read_csv('/content/drive/Shareddrives/DSL_Modeling_B/data/dacon_menu_final_category_property.csv')

# %%
o_menu = cp['menu'].tolist()
o_category = cp['category'].tolist()
o_property = cp['property'].tolist()

# %%
for i in range(len(o_menu)):
    for j in range(len(true)):
        if true['Menu'][j] == o_menu[i]:
            true['category'][j] = o_category[i]
            true['property'][j] = o_property[i]

# %%
true.to_csv("/content/drive/Shareddrives/DSL_Modeling_B/result_true.csv")

# %% [markdown]
# # Category hit 지표

# %%
category_hit = []
for i in range(len(first)):
  if true['category'][i] == first['ctg1'][i]:
    category_hit.append(1)
  elif true['category'][i] == second['ctg2'][i]:
    category_hit.append(0.8)
  elif true['category'][i] == third['ctg3'][i]:
    category_hit.append(0.6)
  else: category_hit.append(0)

# %% [markdown]
# # Property hit 지표

# %%
property_hit = []
for i in range(len(first)):
  if true['property'][i] == first['pp1'][i]:
    property_hit.append(1)
  elif true['property'][i] == second['pp2'][i]:
    property_hit.append(0.8)
  elif true['property'][i] == third['pp3'][i]:
    property_hit.append(0.6)
  else: property_hit.append(0)

# %% [markdown]
# # Hit 지표

# %%
hit = []
for i in range(len(first)):
  if true['Menu'][i] == first['firstrec'][i]:
    hit.append(1)
  elif true['Menu'][i] == second['secondrec'][i]:
    hit.append(1)
  elif true['Menu'][i] == third['thirdrec'][i]:
    hit.append(1)
  else: hit.append(0)

# %% [markdown]
# # 결과 확인

# %%
output = pd.DataFrame([user,first['firstrec'], second['secondrec'], third['thirdrec'], true['Menu'], category_hit, property_hit, hit], 
                      index = ['user','first','second','third','answer',"category_hit", "property_hit", "hit"]).transpose()

# %%
output
# Out:
#     user      first     second       third    answer category_hit  \
# 0   4532     꽁치레몬구이      순살닭갈비   치킨핑거/요거트D  쇠고기모듬장조림            1
# 1   4533     꽃게된장찌개      옥수수스프      꽁치레몬구이     갈릭돈가스            0
# 2   4534      가쯔오장국       콩나물국         무채국      오징어국            1
# 3   4535     참치김치볶음    수제오징어튀김      참치채소볶음      카스테라            0
# 4   4536       오징어국        황태국        미소장국     옥수수스프            0
# 5   4537      가쯔오장국    수원왕갈비통닭         칼국수    우거지된장국            1
# 6   4538     꽃게된장찌개        무채국       가쯔오장국       닭개장            1
# 7   4539     동파삼겹수육     언양식불고기      쇠고기장조림     모둠장조림          0.8
# 8   4540      돼지갈비찜    유자청돈육볶음        제육볶음       닭갈비            1
# 9   4541  모둠튀김*칠리소스      순살닭갈비         깐풍육   순대오징어볶음          0.8
# 10  4542      생선커틀릿     꽁치레몬구이     새우까스*소스     모듬장조림          0.8
# 11  4543  모둠튀김*칠리소스    순대오징어볶음       순살닭갈비     닭오븐구이          0.8
# 12  4544  모둠튀김*칠리소스      순살닭갈비        명태조림      야채튀김          0.8
# 13  4545     곤약어묵볶음     개성감자만두     모듬소세지볶음      연근조림            1
# 14  4546       쑥갓나물  풋고추양파쌈장무침   석박지/청포도주스    교촌간장치킨            0
# 15  4547     통도라지구이   크랜베리멸치볶음     매쉬드포테이토     시금치나물            1
# 16  4548      유부김칫국     호밧젓국찌개         냉이국     미니햄버거            0
# 17  4549     곤약어묵볶음    새우까스*소스       생선커틀릿     순살닭갈비            1
# 18  4550      가쯔오장국     해물된장찌개        연두부탕    차돌박이찌개            1
# 19  4551      햄계란말이     통도라지구이     매쉬드포테이토    옥수수계란찜            1
# 20  4552  모둠튀김*칠리소스      순살닭갈비  후르츠탕수육(황도)     고등어구이          0.8
# 21  4553      꽈리고추찜   크랜베리멸치볶음       시금치나물     애호박나물            1
# 22  4554     꼬시래기무침     오이양파무침     연근깨소스무침    두부양념조림            1
# 23  4555     곤약어묵볶음      햄계란말이     파래김*양념장     감자샐러드            1
# 24  4556      가쯔오장국        맑은국         콩국수     콩비지찌개            1
# 25  4557    파래김*양념장    모듬소세지볶음      곤약어묵볶음    달래두부무침            1
# 26  4558     쇠고기장조림     개성감자만두      등갈비김치찜    삼치된장구이            1
# 27  4559     맑은콩나물국      동태매운탕        부대찌개      미소장국            1
# 28  4560      가쯔오장국       콩나물국      느타리버섯국    청양된장찌개            1
# 29  4561  모둠튀김*칠리소스      가쯔오장국  후르츠탕수육(황도)  주꾸미굴소스볶음          0.8
# 30  4562      군만두*장       쑥갓나물       수수부꾸미    꼬시래기무침            1
# 31  4563     꽃게된장찌개       콩나물국       가쯔오장국      된장찌개            1
# 32  4564     사골우거지국        황태국        된장찌개       감자국            1
# 33  4565    모듬소세지볶음      마늘쫑볶음     비엔나케찹조림      감자채전            1
# 34  4566    마늘종호두조림      짜샤이볶음      달래오이생채      연근조림            1
# 35  4567     고구마그라탕      꽃맛살볶음      해파리겨자채   연두부*양념장            1
# 36  4568     우거지된장국        칼국수        떡만두국       아욱국            1
# 37  4569    연근깨소스무침      시금치나물     진미채오이무침  숯불양념꼬지어묵            1
# 38  4570       누룽지탕       참치야채         참치죽       녹두죽            1
# 39  4571      가쯔오장국        콩국수         맑은국     소고기무국            1
# 40  4572    고추잡채*꽃빵     고구마그라탕     미트볼케찹조림   유자청돈육볶음          0.8
# 41  4573    파래김*양념장     곤약어묵볶음     모듬소세지볶음      감자만두            0
# 42  4574    고추잡채*꽃빵      돼지갈비찜     유자청돈육볶음      제육볶음          0.8
# 43  4575     곤약어묵볶음     개성감자만두       마늘쫑볶음    사각어묵볶음            1
# 44  4576      순살닭갈비  모둠튀김*칠리소스         칼국수      돈육보쌈            1
# 45  4577      수수부꾸미   돈채표고버섯볶음   주꾸미브로콜리숙회    감자양념조림            1
# 46  4578   비엔나구이*케찹   애호박새우젓볶음      참치채소볶음    감자양념조림            1
# 47  4579     올챙이만두국       대구찌개       고추장찌개    민물새우찌개            1
# 48  4580       순두부국     호밧젓국찌개       바지락쑥국       근대국            1
# 49  4581     등갈비김치찜  치킨핑거/요거트D      데리야끼파닭    꽁치레몬구이            1
# 50  4582     참치채소볶음     참치김치볶음     수제오징어튀김  애호박새우젓볶음            1
#
#    property_hit hit
# 0           0.8   0
# 1             0   0
# 2             1   0
# 3             0   0
# 4             1   0
# 5             1   0
# 6             0   0
# 7             0   0
# 8             0   0
# 9             0   0
# 10            0   0
# 11            0   0
# 12            1   0
# 13            0   0
# 14            0   0
# 15            0   0
# 16            0   0
# 17            0   0
# 18          0.8   0
# 19            0   0
# 20            0   0
# 21          0.6   0
# 22            0   0
# 23          0.6   0
# 24            0   0
# 25            0   0
# 26            0   0
# 27            1   0
# 28            0   0
# 29            0   0
# 30          0.8   0
# 31            1   0
# 32            1   0
# 33            0   0
# 34            1   0
# 35          0.6   0
# 36            1   0
# 37            0   0
# 38          0.6   0
# 39            1   0
# 40            0   0
# 41            0   0
# 42          0.6   0
# 43            1   0
# 44            0   0
# 45            0   0
# 46            0   0
# 47          0.8   0
# 48            1   0
# 49            0   0
# 50            1   0

# %%
# category_HIT@3 지표 계산
category_HIT = sum(category_hit)/len(true)
category_HIT
# Out:
# 0.8470588235294116

# %%
# property_HIT@3 지표 계산
property_HIT = sum(property_hit)/len(true)
property_HIT
# Out:
# 0.3764705882352941

# %%
# HIT@3 지표 계산
HIT = sum(hit)/len(true)
HIT
# Out:
# 0.0
